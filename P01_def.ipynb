# %% [markdown]
# ## 1a. Hacer un programa que cargue una imagen y que obtenga y muestre el valor RGB de cada píxel de la imagen sobre el que esté el cursor del ratón.

# %%
import cv2 as cv
import numpy as np

def mouse(event, x, y, flags, param):
    bgr_pixel = param[y, x]
    # Convertir BGR a RGB (opcional pero recomendado para mostrar en RGB)
    rgb_pixel = bgr_pixel[[2, 1, 0]] # Invertir el orden para obtener RGB
    text = f'({x}, {y}), RGB: {rgb_pixel}'
    print(text)

    temp = img.copy()
    cv.putText(temp, text, (10, 30), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)

    cv.imshow('EII', temp)

img = cv.imread('images/eii.png')

cv.imshow('EII', img)

cv.setMouseCallback('EII', mouse, img)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (321, 265), RGB: [160 148 136]
# (200, 11), RGB: [127 187 250]
# (200, 10), RGB: [127 187 250]
# (200, 13), RGB: [127 187 250]
# (199, 22), RGB: [130 190 251]
# (199, 28), RGB: [130 190 251]
# (199, 31), RGB: [134 192 252]
# (199, 35), RGB: [134 192 252]
# (199, 39), RGB: [139 193 249]
# (199, 41), RGB: [148 201 253]
# (199, 44), RGB: [200 218 245]
# (199, 45), RGB: [208 224 253]
# (199, 46), RGB: [215 225 245]
# (199, 48), RGB: [214 228 253]
# (199, 50), RGB: [215 225 245]
# (199, 52), RGB: [215 225 245]
# (199, 53), RGB: [215 225 245]
# (200, 57), RGB: [207 221 247]
# (201, 61), RGB: [200 215 240]
# (201, 65), RGB: [186 210 243]
# (203, 67), RGB: [179 206 241]
# (204, 71), RGB: [158 201 248]
# (205, 75), RGB: [150 203 253]
# (205, 77), RGB: [150 203 253]
# (207, 81), RGB: [148 201 253]
# (208, 85), RGB: [148 201 253]
# (209, 91), RGB: [150 203 253]
# (211, 93), RGB: [150 203 253]
# (213, 99), RGB: [150 203 253]
# (219, 110), RGB: [155 207 254]
# (221, 114), RGB: [155 207 254]
# (228, 123), RGB: [163 210 253]
# (231, 127), RGB: [124 130 148]
# (234, 133), RGB: [154 140 126]
# (238, 139), RGB: [131 120 108]
# (243, 148), RGB: [159 145 131]
# (250, 157), RGB: [159 145 131]
# (253, 161), RGB: [164 148 132]
# (259, 168), RGB: [163 162 162]
# (266, 177), RGB: [166 152 138]
# (269, 181), RGB: [165 151 136]
# (275, 187), RGB: [160 148 136]
# (280, 196), RGB: [160 148 136]
# (282, 198), RGB: [158 148 138]
# (287, 204), RGB: [161 150 140]
# (292, 210), RGB: [163 152 142]
# (293, 213), RGB: [163 152 142]
# (297, 217), RGB: [167 157 148]
# (300, 221), RGB: [149 138 127]
# (302, 225), RGB: [170 158 145]
# (305, 228), RGB: [168 156 144]
# (308, 233), RGB: [167 154 143]
# (315, 242), RGB: [170 158 145]
# (317, 246), RGB: [175 166 157]
# (320, 250), RGB: [168 156 144]
# (325, 258), RGB: [164 151 140]
# (327, 262), RGB: [167 154 143]
# (330, 266), RGB: [170 156 142]
# (335, 272), RGB: [64 65 71]
# (339, 276), RGB: [167 154 143]
# (346, 285), RGB: [160 148 136]
# (353, 295), RGB: [137 125 113]
# (360, 304), RGB: [156 144 134]
# (362, 308), RGB: [156 144 134]
# (372, 318), RGB: [146 134 123]
# (381, 327), RGB: [156 144 134]
# (385, 331), RGB: [158 148 138]
# (397, 342), RGB: [153 141 131]
# (408, 354), RGB: [153 141 131]
# (419, 361), RGB: [140 129 119]
# (448, 359), RGB: [87 89 97]
# (441, 352), RGB: [121 120 126]
# (430, 343), RGB: [19 18 15]
# (424, 339), RGB: [155 152 150]
# (419, 332), RGB: [165 153 141]
# (415, 328), RGB: [167 154 143]
# (410, 322), RGB: [154 140 126]
# (409, 318), RGB: [154 140 126]
# (406, 312), RGB: [164 148 132]
# (405, 308), RGB: [160 144 127]
# (405, 306), RGB: [159 145 131]
# (405, 305), RGB: [160 144 127]
# (404, 304), RGB: [159 145 131]
# (404, 303), RGB: [160 144 127]
# (404, 302), RGB: [160 144 127]
# (404, 301), RGB: [160 144 127]
# (404, 300), RGB: [154 140 126]
# (404, 298), RGB: [165 153 141]
# (403, 297), RGB: [131 120 108]
# (403, 293), RGB: [152 136 120]
# (403, 292), RGB: [152 136 120]
# (403, 289), RGB: [163 149 135]
# (403, 288), RGB: [165 151 136]
# (403, 285), RGB: [159 145 131]
# (402, 285), RGB: [161 147 133]
# (402, 284), RGB: [159 145 131]
# (402, 283), RGB: [161 147 133]
# (401, 283), RGB: [159 145 131]
# (401, 282), RGB: [159 145 131]
# (401, 281), RGB: [161 147 133]
# (401, 280), RGB: [161 147 133]
# (400, 280), RGB: [161 147 133]
# (400, 279), RGB: [159 145 131]
# (400, 278), RGB: [159 145 131]
# (400, 277), RGB: [159 145 131]
# (400, 276), RGB: [156 143 130]
# (399, 276), RGB: [159 145 131]
# (399, 275), RGB: [163 149 135]
# (399, 274), RGB: [159 145 131]
# (399, 273), RGB: [154 140 126]
# (399, 272), RGB: [159 145 131]
# (399, 271), RGB: [161 147 133]
# (399, 270), RGB: [163 149 135]
# (399, 269), RGB: [161 147 133]
# (399, 268), RGB: [163 149 135]
# (399, 266), RGB: [163 149 135]
# (399, 265), RGB: [163 149 135]
# (399, 264), RGB: [163 149 135]
# (399, 263), RGB: [165 151 136]
# (399, 262), RGB: [163 149 135]
# (399, 261), RGB: [165 151 136]
# (399, 260), RGB: [163 149 135]
# (399, 259), RGB: [165 151 136]
# (399, 258), RGB: [161 147 133]
# (399, 257), RGB: [161 147 133]
# (399, 256), RGB: [161 147 133]
# (399, 255), RGB: [161 147 133]
# (399, 254), RGB: [161 147 133]
# (399, 253), RGB: [161 147 133]
# (399, 252), RGB: [163 149 135]
# (399, 251), RGB: [161 147 133]
# (399, 249), RGB: [161 147 133]
# (399, 250), RGB: [161 147 133]
# (399, 251), RGB: [161 147 133]
# (400, 254), RGB: [159 145 131]
# (403, 262), RGB: [163 149 135]
# (404, 264), RGB: [161 147 133]
# (405, 268), RGB: [163 149 135]
# (407, 272), RGB: [161 147 133]
# (408, 274), RGB: [164 151 140]
# (408, 276), RGB: [162 150 138]
# (409, 276), RGB: [162 150 138]
# (409, 277), RGB: [164 151 140]
# (410, 278), RGB: [167 154 143]
# (410, 279), RGB: [167 154 143]
# (410, 280), RGB: [165 153 141]
# (411, 281), RGB: [170 158 145]
# (412, 283), RGB: [167 154 143]
# (413, 284), RGB: [160 148 136]
# (413, 285), RGB: [153 141 131]
# (413, 286), RGB: [146 134 123]
# (414, 287), RGB: [137 125 113]
# (414, 288), RGB: [140 129 119]
# (415, 288), RGB: [170 158 145]
# (415, 289), RGB: [170 158 145]
# (415, 290), RGB: [170 158 145]
# (416, 290), RGB: [171 159 148]
# (416, 291), RGB: [170 158 145]
# (417, 292), RGB: [167 153 140]
# (417, 293), RGB: [166 152 138]
# (418, 293), RGB: [167 153 140]
# (418, 294), RGB: [149 138 127]
# (419, 295), RGB: [153 141 131]
# (419, 296), RGB: [161 147 133]
# (420, 296), RGB: [156 143 130]
# (421, 297), RGB: [149 138 127]
# (422, 298), RGB: [165 155 145]
# (423, 298), RGB: [165 155 145]
# (423, 299), RGB: [168 156 144]
# (424, 299), RGB: [165 153 141]
# (424, 300), RGB: [158 148 138]
# (426, 301), RGB: [84 87 84]
# (426, 302), RGB: [84 87 84]
# (427, 303), RGB: [64 65 71]
# (427, 304), RGB: [133 131 134]
# (428, 304), RGB: [133 131 134]
# (428, 305), RGB: [167 157 148]
# (429, 305), RGB: [167 157 148]
# (429, 306), RGB: [140 129 119]
# (429, 307), RGB: [183 175 165]
# (430, 308), RGB: [121 120 126]
# (430, 310), RGB: [23 23 29]
# (431, 311), RGB: [23 23 29]
# (431, 312), RGB: [23 23 29]
# (431, 313), RGB: [19 18 15]
# (432, 313), RGB: [23 23 29]
# (432, 314), RGB: [19 18 15]
# (433, 315), RGB: [12 10  9]
# (434, 316), RGB: [45 51 51]
# (434, 317), RGB: [177 185 202]
# (435, 317), RGB: [177 185 202]
# (435, 318), RGB: [168 174 186]
# (436, 318), RGB: [180 183 188]
# (436, 319), RGB: [180 183 188]
# (437, 320), RGB: [161 165 176]
# (438, 321), RGB: [64 65 71]
# (439, 322), RGB: [150 153 161]
# (439, 323), RGB: [150 153 161]
# (440, 323), RGB: [139 140 148]
# (440, 324), RGB: [139 140 148]
# (440, 325), RGB: [139 140 148]
# (440, 326), RGB: [139 140 148]
# (440, 327), RGB: [139 140 148]
# (440, 328), RGB: [139 140 148]
# (440, 329), RGB: [139 140 148]
# (440, 330), RGB: [139 140 148]
# (440, 332), RGB: [139 140 148]
# (440, 333), RGB: [139 140 148]
# (440, 334), RGB: [139 140 148]
# (439, 334), RGB: [150 153 161]
# (439, 335), RGB: [150 153 161]
# (438, 335), RGB: [87 89 97]
# (437, 335), RGB: [55 56 64]
# (436, 335), RGB: [19 18 15]
# (436, 336), RGB: [23 23 29]
# (435, 337), RGB: [23 23 29]
# (435, 338), RGB: [23 23 29]
# (435, 339), RGB: [23 23 29]
# (434, 339), RGB: [23 23 29]
# (434, 340), RGB: [23 23 29]
# (434, 341), RGB: [23 23 29]
# (434, 342), RGB: [23 23 29]
# (433, 343), RGB: [32 36 43]
# (433, 344), RGB: [23 23 29]
# (434, 344), RGB: [23 23 29]
# (434, 343), RGB: [23 23 29]
# (435, 341), RGB: [23 23 29]
# (435, 340), RGB: [23 23 29]
# (435, 339), RGB: [23 23 29]
# (435, 338), RGB: [23 23 29]
# (435, 337), RGB: [23 23 29]
# (436, 337), RGB: [23 23 29]
# (436, 335), RGB: [19 18 15]
# (437, 334), RGB: [55 56 64]
# (437, 333), RGB: [55 56 64]
# (437, 331), RGB: [19 18 15]
# (438, 330), RGB: [74 78 73]
# (438, 329), RGB: [64 65 71]
# (438, 326), RGB: [64 65 71]
# (439, 325), RGB: [150 153 161]
# (439, 323), RGB: [150 153 161]
# (439, 322), RGB: [150 153 161]
# (440, 320), RGB: [133 131 134]
# (440, 319), RGB: [139 140 148]
# (440, 318), RGB: [168 174 186]
# (440, 316), RGB: [74 78 73]
# (440, 315), RGB: [12 10  9]
# (440, 314), RGB: [23 23 29]
# (440, 312), RGB: [34 27 22]
# (440, 310), RGB: [32 36 43]
# (440, 309), RGB: [19 18 15]
# (440, 307), RGB: [187 190 194]
# (440, 305), RGB: [165 153 141]
# (440, 304), RGB: [160 148 136]
# (440, 302), RGB: [160 148 136]
# (440, 301), RGB: [167 154 143]
# (440, 300), RGB: [174 161 147]
# (440, 299), RGB: [176 164 151]
# (440, 298), RGB: [171 159 148]
# (440, 297), RGB: [156 144 134]
# (440, 296), RGB: [156 143 130]
# (440, 295), RGB: [172 162 152]
# (440, 294), RGB: [137 125 113]

# %% [markdown]
# ## 1b. Hacer un programa para dibujar las siguientes primitivas con el ratón
# - Líneas
# - Rectángulos
# - Círculos
# - Especificar el color en RGB de las primitivas
# - Definir el grosor de las líneas

# %%
import cv2 as cv
import numpy as np

def nothing(x):
    pass

cv.namedWindow('Dibujo')

# Trackbars para color
cv.createTrackbar('R','Dibujo',0,255,nothing)
cv.createTrackbar('G','Dibujo',0,255,nothing)
cv.createTrackbar('B','Dibujo',0,255,nothing)

# Trackbar para seleccionar primitiva: 0 = Línea, 1 = Rectángulo, 2 = Círculo
cv.createTrackbar('Primitiva', 'Dibujo', 0, 2, nothing)

# Trackbar para grosor de línea (mínimo 1, máximo 20)
cv.createTrackbar('Grosor', 'Dibujo', 1, 20, nothing)

cv.createTrackbar('Relleno', 'Dibujo', 0, 1, nothing) 

print("0: Líneas // 1: Rectángulos // 2: Círculos")

drawing = False
ix, iy = -1, -1
img = np.ones((500, 700, 3), np.uint8) * 255

def mouse(event, x, y, flags, param):
    global ix, iy, drawing, shape, color, thickness, canvas

    if event == cv.EVENT_LBUTTONDOWN:
        drawing = True
        ix, iy = x, y

    elif event == cv.EVENT_MOUSEMOVE and drawing:
        temp = img.copy()
        if shape == 'line':
            cv.line(temp, (ix, iy), (x, y), color, thickness)
        elif shape == 'rect':
            cv.rectangle(temp, (ix, iy), (x, y), color, thickness)
        elif shape == 'circle':
            radius = int(np.sqrt((x - ix) ** 2 + (y - iy) ** 2))    
            cv.circle(temp, (ix, iy), radius, color, thickness)

        cv.imshow('Dibujo', temp)

    elif event == cv.EVENT_LBUTTONUP:
        drawing = False
        if shape == 'line':
            cv.line(img, (ix, iy), (x, y), color, thickness)
        elif shape == 'rect':
            cv.rectangle(img, (ix, iy), (x, y), color, thickness)
        elif shape == 'circle':
            radius = int(np.sqrt((x - ix) ** 2 + (y - iy) ** 2))    
            cv.circle(img, (ix, iy), radius, color, thickness)

        cv.imshow('Dibujo', img)

cv.setMouseCallback('Dibujo', mouse)

while True:

    # Leer la posición actual de la trackbar de primitiva
    primitiva = cv.getTrackbarPos('Primitiva', 'Dibujo')

    # Elegir la forma según el valor
    if primitiva == 0:
        shape = 'line'
    elif primitiva == 1:
        shape = 'rect'
    elif primitiva == 2:
        shape = 'circle'

    # Leer los valores de color RGB
    r = cv.getTrackbarPos('R', 'Dibujo')
    g = cv.getTrackbarPos('G', 'Dibujo')
    b = cv.getTrackbarPos('B', 'Dibujo')
    color = (b, g, r)

     # Leer el grosor
    thickness = cv.getTrackbarPos('Grosor', 'Dibujo')

    #cv.imshow('Dibujo', img)

    # Mostrar en consola
    print(f'Primitiva: {shape} | Color (R,G,B): ({r}, {g}, {b}) | Grosor: {thickness}   ', end='\r')

    # Salir con ESC
    k = cv.waitKey(100)
    if k == 27:
        break

cv.destroyAllWindows()
# Out:
# 0: Líneas // 1: Rectángulos // 2: Círculos
# Primitiva: rect | Color (R,G,B): (0, 0, 0) | Grosor: 1

# %% [markdown]
# # 2. Mejoras del programa:
# - Permitir crear figuras rellenas (seleccionar a través de la interfaz)
# - Poder crear otras primitivas (construir polilíneas y polígonos, elipses…)
# - Guardar el dibujo como un vídeo para ver cómo se realizó paso a paso
# - Aportación propia

# %%
import cv2 as cv
import numpy as np
import datetime

def nothing(x):
    pass

cv.namedWindow('Dibujo')

cv.createTrackbar('R','Dibujo',0,255,nothing)
cv.createTrackbar('G','Dibujo',0,255,nothing)
cv.createTrackbar('B','Dibujo',0,255,nothing)

cv.createTrackbar('Primitiva', 'Dibujo', 0, 5, nothing)

cv.createTrackbar('Grosor', 'Dibujo', 1, 20, nothing)

cv.createTrackbar('Relleno', 'Dibujo', 0, 1, nothing) 

print("0: Líneas // 1: Rectángulos // 2: Círculos // 3: Elipses // 4: Polilíneas // 5: Polígonos")
print("0: Contorno // 1: Relleno")
print("ESC: Salir // 'c': Limpiar // 'g': Guardar imagen")

drawing = False
ix, iy = -1, -1
img = np.ones((500, 700, 3), np.uint8) * 255
puntos = []

height, width, _ = img.shape        
fps = 24                             
fourcc = cv.VideoWriter_fourcc(*'mp4v') 
filename = datetime.datetime.now().strftime("dibujo_%Y%m%d_%H%M%S.mp4")
out = cv.VideoWriter(filename, fourcc, fps, (width, height))

def mouse(event, x, y, flags, param):
    global ix, iy, drawing, shape, color, thickness, canvas

    if shape in ['line', 'rect', 'circle', 'ellipse']:
        if event == cv.EVENT_LBUTTONDOWN:
            drawing = True
            ix, iy = x, y

        elif event == cv.EVENT_MOUSEMOVE and drawing:
            temp = img.copy()
            if shape == 'line':
                cv.line(temp, (ix, iy), (x, y), color, thickness)
            elif shape == 'rect':
                cv.rectangle(temp, (ix, iy), (x, y), color, thickness_actual)
            elif shape == 'circle':
                radius = int(np.sqrt((x - ix) ** 2 + (y - iy) ** 2))    
                cv.circle(temp, (ix, iy), radius, color, thickness_actual)
            elif shape == 'ellipse':
                axes = (abs(x - ix), abs(y - iy))
                cv.ellipse(temp, (ix, iy), axes, 0, 0, 360, color, thickness_actual)

            cv.imshow('Dibujo', temp)
            out.write(temp)

        elif event == cv.EVENT_LBUTTONUP:
            drawing = False
            if shape == 'line':
                cv.line(img, (ix, iy), (x, y), color, thickness)
            elif shape == 'rect':
                cv.rectangle(img, (ix, iy), (x, y), color, thickness_actual)
            elif shape == 'circle':
                radius = int(np.sqrt((x - ix) ** 2 + (y - iy) ** 2))    
                cv.circle(img, (ix, iy), radius, color, thickness_actual)
            elif shape == 'ellipse':
                axes = (abs(x - ix), abs(y - iy))
                cv.ellipse(img, (ix, iy), axes, 0, 0, 360, color, thickness_actual)

            cv.imshow('Dibujo', img)
            out.write(img)
    
    elif shape in ['polyline', 'polygon']:
        if event == cv.EVENT_LBUTTONDOWN:
            puntos.append((x, y))
            temp = img.copy()  
            for i in range(1, len(puntos)):
                cv.line(temp, puntos[i-1], puntos[i], color, thickness)
            cv.imshow('Dibujo', temp)
            out.write(temp)

        elif event == cv.EVENT_RBUTTONDOWN and len(puntos) > 1:

            if shape == 'polygon':
                puntos_array = np.array(puntos, dtype=np.int32).reshape((-1, 1, 2))
                
                if relleno == 1:
                    cv.fillPoly(img, [puntos_array], color)

                cv.polylines(img, [puntos_array], isClosed=True, color=color, thickness=thickness)
                cv.imshow('Dibujo', img)
                out.write(img)

            elif shape == 'polyline':
                puntos_polylines = np.array(puntos, dtype=np.int32).reshape((-1, 1, 2))

                cv.polylines(img, [puntos_polylines], isClosed=False, color=color, thickness=thickness)
                cv.imshow('Dibujo', img)
                out.write(img)

            puntos.clear()  
        
cv.setMouseCallback('Dibujo', mouse)

while True:

    primitiva = cv.getTrackbarPos('Primitiva', 'Dibujo')

    if primitiva == 0:
        shape = 'line'
    elif primitiva == 1:
        shape = 'rect'
    elif primitiva == 2:
        shape = 'circle'
    elif primitiva == 3:
        shape = 'ellipse'
    elif primitiva == 4:
        shape = 'polyline'
    elif primitiva == 5:
        shape = 'polygon'

    r = cv.getTrackbarPos('R', 'Dibujo')
    g = cv.getTrackbarPos('G', 'Dibujo')
    b = cv.getTrackbarPos('B', 'Dibujo')
    color = (b, g, r)

    thickness = cv.getTrackbarPos('Grosor', 'Dibujo')

    relleno = cv.getTrackbarPos('Relleno', 'Dibujo')

    thickness_actual = thickness if relleno == 0 else -1

    print(f'Primitiva: {shape} | Color (R,G,B): ({r}, {g}, {b}) | Grosor: {thickness} | Relleno: {relleno}   ', end='\r')

    k = cv.waitKey(100)
    if k == 27:
        break

    elif k == ord('c'):  
        img[:] = 255
        puntos.clear()

    elif k == ord('g'): 
        filename = datetime.datetime.now().strftime("dibujo_%Y%m%d_%H%M%S.png")
        cv.imwrite(filename, img)
    

out.release()
cv.destroyAllWindows()
# Out:
# 0: Líneas // 1: Rectángulos // 2: Círculos // 3: Elipses // 4: Polilíneas // 5: Polígonos
# 0: Contorno // 1: Relleno
# Primitiva: line | Color (R,G,B): (0, 0, 0) | Grosor: 1 | Relleno: 0
